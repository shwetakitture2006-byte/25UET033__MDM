# %% [markdown]
# <a href="https://colab.research.google.com/github/shwetakitture2006-byte/25UET033__MDM/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num= int (input ("enter number"))
if num%2==0:
          print("number is even")
# Out:
# enter number20
# number is even

# %%
age=17
if age>18:
  print("eligibal for voting")

# %%
age=20
if age>=18:
  print("eligibal for voting")
else:
  print("not eligibal")
# Out:
# eligibal for voting

# %%
mark=95
if mark>=90:
  print("grade A")
elif mark<90 and mark>=80:
  print("grade B")
elif mark<80 and mark>=70:
  print("grade C")
elif mark<70 and mark>=35:
  print("grade D")
else:
  print("fail")
# Out:
# grade A

# %%
age= int (input ("enter your age "))
citizen= input("enter your citizen ")
if age>=18:
  if(citizen== "indian"):
    print("you are eligibal for vote")
  else:
    print("you are not eligibal for vote")
# Out:
# enter your age 20
# enter your citizen indian
# you are eligibal for vote
