# %% [markdown]
# <a href="https://colab.research.google.com/github/shwetakitture2006-byte/25UET033__MDM/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello",end=' ');
print("word");
# Out:
# hello word

# %%
a=5;
b=6;
print("sum",a+b);
# Out:
# sum 11

# %%
print("hello\netc")
# Out:
# hello
# etc

# %%
print("hello\tworld")
# Out:
# hello	world

# %%
print("java","python","c++",sep='-');
# Out:
# java-python-c++

# %%
name=input("enter your name:")
print("my name is",name)
print(type(name))
# Out:
# enter your name:shweta
# my name is shweta
# <class 'str'>

# %%
age=int(input("enter your age"))
print("my age is after one year is",age+1)
# Out:
# enter your age20
# my age is after one year is 21

# %%
a=int(input("first no:"))
b=int(input("second no:"))
print("sum",a+b)
print(type(a))
# Out:
# first no:1
# second no:2
# sum 3
# <class 'int'>

# %%
name="shweta"
age=20
college="dkte"
print(f"hello my name is {name} and my age is {age} also i am studying in {college}")
# Out:
# hello my name is shweta and my age is 20 also i am studying in dkte
